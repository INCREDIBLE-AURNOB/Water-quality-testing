# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from sklearn.utils import shuffle

# %% [markdown]
# ![https://s25180.pcdn.co/wp-content/uploads/2018/08/iStock-692910116_crop.jpg](attachment:water.jpg)

# %%
## Read the dataset
df=pd.read_csv('water_potability.csv')
df=shuffle(df)
df
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 2484  6.653650  172.584512  34816.444538     8.289307  293.611048
# 715        NaN  193.410141  14472.391549     5.640672  322.674462
# 2596       NaN  172.968203  24445.987540     7.032643         NaN
# 3030  8.040392  200.637576  12999.144804     6.696356  356.870041
# 511   7.291957  202.329044  21891.677159     7.628747  339.829014
# ...        ...         ...           ...          ...         ...
# 2211  4.808040  186.160570  19118.050299     7.054444  359.406236
# 847   8.990317  195.809028  23728.294015     7.508305  348.714613
# 2821  9.752703  269.640378  10194.325411     7.978044  298.082462
# 478   7.417570  193.771878  23207.092841     7.472115         NaN
# 2817  8.247958  195.539536  28327.167338     5.378286  281.229853
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability
# 2484    389.471149       15.872474        67.976869   4.871406           0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3276 entries, 2484 to 2817
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ph               2785 non-null   float64
#  1   Hardness         3276 non-null   float64
#  2   Solids           3276 non-null   float64
#  3   Chloramines      3276 non-null   float64
#  4   Sulfate          2495 non-null   float64
#  5   Conductivity     3276 non-null   float64
#  6   Organic_carbon   3276 non-null   float64
#  7   Trihalomethanes  3114 non-null   float64
#  8   Turbidity        3276 non-null   float64
#  9   Potability       3276 non-null   int64
# dtypes: float64(9), int64(1)
# memory usage: 281.5 KB

# %%
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# ...

# %% [markdown]
# ### Data Visualization

# %%
sns.set_theme(style="ticks")
f, ax = plt.subplots(figsize=(10,5))
sns.despine(f)
sns.histplot(df,x="ph", hue="Potability",multiple="stack",palette="light:m_r",edgecolor=".3")
plt.title("pH level count")
plt.xlabel('ph Level')
# Out:
# Text(0.5, 0, 'ph Level')

# %% [markdown]
# ### 	Chloramines	Sulfate	Organic_carbon	and Trihalomethanes plays a great role in water quality.The density of these elements measure the quality. So that I visualize the density of these elements.

# %%
fig = sns.kdeplot(df['Chloramines'], shade=True, color="r")
fig = sns.kdeplot(df['Sulfate'], shade=True, color="b")
fig = sns.kdeplot(df['Organic_carbon'], shade=True, color="g")
fig = sns.kdeplot(df['Trihalomethanes'], shade=True, color="r")
plt.show()

# %% [markdown]
# ### We can see from the above graph is that the density of Chlorimines is high. So this is one of the most important element for water quality. Now we have to see is this is good or bad for water quality.

# %%
sns.set_theme(style="ticks")
f, ax = plt.subplots(figsize=(10,5))
sns.despine(f)

sns.histplot(df,x="Chloramines", hue="Potability",multiple="stack",palette="light:m_r",edgecolor=".3")
# Out:
# <AxesSubplot:xlabel='Chloramines', ylabel='Count'>

# %% [markdown]
# ### From the above graph we are able to understand that the quantity of Chloramines is not more or not less is good for drinkable water.

# %% [markdown]
# Turbidity is the measure of relative clarity of a liquid. ... Material that causes water to be turbid include clay, silt, very tiny inorganic and organic matter, algae, dissolved colored organic compounds, and plankton and other microscopic organisms. Turbidity makes water cloudy or opaque.

# %%
sns.set_theme(style="ticks")
f, ax = plt.subplots(figsize=(10,5))
sns.despine(f)

sns.histplot(df,x="Turbidity", hue="Potability",multiple="stack",palette="flare",edgecolor=".3")
# Out:
# <AxesSubplot:xlabel='Turbidity', ylabel='Count'>

# %% [markdown]
# #### The term hardness was originally applied to waters that were hard to wash in, referring to the soap wastingproperties of hard water. ... Dissolved calcium and magnesium salts are primarily responsible for most scaling in pipes and water heaters and cause numerous problems in laundry, kitchen, and bath.

# %% [markdown]
# ![https://thumbs.dreamstime.com/b/water-hardness-scale-soft-to-very-hard-83373799.jpg](attachment:water_hardness.jpg)

# %%
df['Hardness'].unique()
# Out:
# array([172.58451221, 193.41014064, 172.96820284, ..., 269.64037809,
#        193.77187837, 195.53953591])

# %%
def f(x):
    if x<17.1:
        x="Soft"
    elif 17.1<x<60:
        x="Slightly hard"
    elif 60 <x <120:
        x="Moderately hard"
    elif 120 <x <180:
        x="Hard"
    elif x > 180:
        x="very hard"
    return x

# %%
df['Hard'] = df['Hardness'].apply(f)

# %% [markdown]
# #### We can see that the probability of hardness is mostly in this dataset

# %%
sns.set_theme(style="ticks")
f, ax = plt.subplots(figsize=(10,10))
sns.despine(f)

sns.histplot(df,x="Hardness", hue="Hard",multiple="stack",palette="husl",edgecolor=".3")
# Out:
# <AxesSubplot:xlabel='Hardness', ylabel='Count'>

# %%
df.head()
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 2484  6.653650  172.584512  34816.444538     8.289307  293.611048
# 715        NaN  193.410141  14472.391549     5.640672  322.674462
# 2596       NaN  172.968203  24445.987540     7.032643         NaN
# 3030  8.040392  200.637576  12999.144804     6.696356  356.870041
# 511   7.291957  202.329044  21891.677159     7.628747  339.829014
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability  \
# 2484    389.471149       15.872474        67.976869   4.871406           0
# 715     431.457337       12.721922        92.758852   4.414819           1
# 2596    571.628892       11.549877        56.499207   4.725347           0
# 3030    394.017732       11.100407        43.625910   3.017796           0
# 511     379.270122        7.654956        64.021523   4.237644           0
#
#            Hard
# 2484       Hard
# 715   very hard
# 2596       Hard
# 3030  very hard
# 511   very hard

# %% [markdown]
# ###                                                             Conductivity of water

# %% [markdown]
# ![https://www.google.com/url?sa=i&url=https%3A%2F%2Fwww.quora.com%2FWhy-is-the-water-of-low-electrical-conductivity-used-in-water-treatment-system-in-boilers-I-know-its-related-to-scaling-but-what-is-the-relationship-between-scale-formation-and-electrical-conductivity&psig=AOvVaw0SzD9C22E83AdyhIvEWStX&ust=1637946283881000&source=images&cd=vfe&ved=0CAsQjRxqFwoTCPjZ08r_s_QCFQAAAAAdAAAAABAU](attachment:conductivity.jpg)

# %%
sns.set_theme(style="ticks")
f, ax = plt.subplots(figsize=(10,5))
sns.despine(f)

sns.histplot(df,x="Conductivity", hue="Potability",multiple="stack",palette="ch:s=.25,rot=-.25",edgecolor=".3")
# Out:
# <AxesSubplot:xlabel='Conductivity', ylabel='Count'>

# %%
y = df['Potability']

plt.pie(y)
plt.show()

# %% [markdown]
# #### High quality deionized water has a conductivity of about 0.05 μS/cm at 25 °C, typical drinking water is in the range of 200–800 μS/cm, while sea water is about 50 mS/cm (or 50,000 μS/cm). Conductivity is traditionally determined by connecting the electrolyte in a Wheatstone bridge

# %% [markdown]
# # Feature Engineering

# %%
df.describe()
# Out:
#                 ph     Hardness        Solids  Chloramines      Sulfate  \
# count  2785.000000  3276.000000   3276.000000  3276.000000  2495.000000
# mean      7.080795   196.369496  22014.092526     7.122277   333.775777
# std       1.594320    32.879761   8768.570828     1.583085    41.416840
# min       0.000000    47.432000    320.942611     0.352000   129.000000
# 25%       6.093092   176.850538  15666.690297     6.127421   307.699498
# 50%       7.036752   196.967627  20927.833607     7.130299   333.073546
# 75%       8.062066   216.667456  27332.762127     8.114887   359.950170
# max      14.000000   323.124000  61227.196008    13.127000   481.030642
#
#        Conductivity  Organic_carbon  Trihalomethanes    Turbidity   Potability
# count   3276.000000     3276.000000      3114.000000  3276.000000  3276.000000
# mean     426.205111       14.284970        66.396293     3.966786     0.390110
# std       80.824064        3.308162        16.175008     0.780382     0.487849
# ...

# %%
## Cheaking null values
df.isnull().sum()
# Out:
# ph                 491
# Hardness             0
# Solids               0
# Chloramines          0
# Sulfate            781
# Conductivity         0
# Organic_carbon       0
# Trihalomethanes    162
# Turbidity            0
# Potability           0
# Hard                 0
# dtype: int64

# %% [markdown]
# #### We can see there are so many missing values in ph , Sulfate and Trihalmethanes. The number of missing values is so high so I am going to replace the missing values with median.

# %% [markdown]
# #### It is the best way to handle missing values as in this way the data is not gone or lose any data

# %%
df['Sulfate'] = df['Sulfate'].replace(np.nan,0)
df['ph'] = df['ph'].replace(np.nan,0)
df['Trihalomethanes'] = df['Trihalomethanes'].replace(np.nan,0)

# %%
df["ph"]=df["ph"].fillna(df['ph'].median)
df["Sulfate"]=df["Sulfate"].fillna(df['Sulfate'].median)
df["Trihalomethanes"]=df["Trihalomethanes"].fillna(df['Trihalomethanes'].median)

# %%
df.isnull().sum()
# Out:
# ph                 0
# Hardness           0
# Solids             0
# Chloramines        0
# Sulfate            0
# Conductivity       0
# Organic_carbon     0
# Trihalomethanes    0
# Turbidity          0
# Potability         0
# Hard               0
# dtype: int64

# %%
df.head()
# Out:
#             ph    Hardness        Solids  Chloramines     Sulfate  \
# 2484  6.653650  172.584512  34816.444538     8.289307  293.611048
# 715   0.000000  193.410141  14472.391549     5.640672  322.674462
# 2596  0.000000  172.968203  24445.987540     7.032643    0.000000
# 3030  8.040392  200.637576  12999.144804     6.696356  356.870041
# 511   7.291957  202.329044  21891.677159     7.628747  339.829014
#
#       Conductivity  Organic_carbon  Trihalomethanes  Turbidity  Potability  \
# 2484    389.471149       15.872474        67.976869   4.871406           0
# 715     431.457337       12.721922        92.758852   4.414819           1
# 2596    571.628892       11.549877        56.499207   4.725347           0
# 3030    394.017732       11.100407        43.625910   3.017796           0
# 511     379.270122        7.654956        64.021523   4.237644           0
#
#            Hard
# 2484       Hard
# 715   very hard
# 2596       Hard
# 3030  very hard
# 511   very hard

# %%
df["Hardness"].shape
# Out:
# (3276,)

# %%
df.drop('Hard',axis=1,inplace=True)

# %% [markdown]
# ## Correlation checking

# %%
data=df.corr()
features=data.index
plt.figure(figsize=(10,10))

#Plotting heatmap with Seaborn

s=sns.heatmap(df[features].corr(),annot=True,cmap='RdYlGn')

# %% [markdown]
# ### Finding Outliers

# %% [markdown]
# #### The best way to find the outliers is to visualize.The data points which fall below Q1 – 1.5 IQR or above Q3 + 1.5 IQR are outliers.where Q1 and Q3 are the 25th and 75th percentile of the dataset respectively, and IQR represents the inter-quartile range and given by Q3 – Q1

# %%
def outliers(x):
    for i in x:
        plt.boxplot(df[i])
        plt.title(i)
        plt.show()

# %%
col=["ph","Hardness","Solids","Chloramines","Sulfate","Conductivity","Organic_carbon","Turbidity","Trihalomethanes"]
outliers(col)

# %%
df.shape
# Out:
# (3276, 10)

# %%
## Remove the outliers
def drop_outliers(data,feature):
    iqr=1.5 * (np.percentile(data[feature],80)-np.percentile(data[feature],10))
    data.drop(data[data[feature]> (iqr+np.percentile(data[feature],80))].index,inplace=True)
    data.drop(data[data[feature]< (np.percentile(data[feature],10)-iqr)].index,inplace=True)

# %%
drop_outliers(df,'ph')
drop_outliers(df,'Hardness')
drop_outliers(df,'Solids')
drop_outliers(df,'Chloramines')
drop_outliers(df,'Sulfate')
drop_outliers(df,'Conductivity')
drop_outliers(df,'Organic_carbon')
drop_outliers(df,'Trihalomethanes')
drop_outliers(df,'Turbidity')

# %%
df.shape
# Out:
# (3265, 10)

# %% [markdown]
# ## Standardizing the data

# %%
x = df.drop('Potability',axis=1).values
y = df['Potability'].values

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2,random_state=42)

# %%
x_train.shape,y_train.shape
# Out:
# ((2612, 9), (2612,))

# %%
x_test.shape,y_test.shape
# Out:
# ((653, 9), (653,))

# %% [markdown]
# ### Sample Scaling

# %%
from sklearn.preprocessing import StandardScaler    
st_x= StandardScaler()    
x_train= st_x.fit_transform(x_train)    
x_test= st_x.transform(x_test)

# %%
x_test
# Out:
# array([[ 0.1805243 , -1.66917967, -1.05262236, ...,  0.85563979,
#          1.07848282, -2.24139463],
#        [ 0.26760006,  0.70454588,  0.65776624, ...,  1.58437424,
#          0.25226524, -1.19077057],
#        [ 0.86369659, -0.45334916,  1.11012063, ..., -1.2451332 ,
#          0.92051744, -2.13269602],
#        ...,
#        [ 0.29169311,  0.83478392,  0.84899081, ..., -0.91897052,
#          0.22145174,  0.76482989],
#        [ 0.37462987, -0.6891567 , -0.3026031 , ..., -2.15583491,
#          1.20707139, -0.74196714],
#        [ 0.64092331, -0.261387  ,  1.20120747, ...,  1.70283131,
#         -0.7702161 ,  0.61515973]])

# %% [markdown]
# ## Model selection

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import RandomizedSearchCV,GridSearchCV

# %% [markdown]
# ## Hyper-parameter tuning

# %%
lr=LogisticRegression(random_state=42)
knn=KNeighborsClassifier()
dt=DecisionTreeClassifier()
rf=RandomForestClassifier()
ada=AdaBoostClassifier()
xgb=XGBClassifier(eval_metric='logloss',use_label_encoder=False)

# parameter for KNN
para_knn={'n_neighbors':np.arange(1,50)}
grid_knn=GridSearchCV(knn,param_grid=para_knn,cv=5)

#parameter for decision tree
para_dt={'criterion':['gini','entropy'],'max_depth':np.arange(1,50),
         'min_samples_leaf':[1,2,4,5,10,20,30,40,50,80,100]}
grid_dt=GridSearchCV(dt,param_grid=para_dt,cv=5)

#parameter for Random Forest
params_rf={'n_estimators':[100,200,350,500],
           'min_samples_leaf':[2,10,30,50,80,100]}
grid_rf=GridSearchCV(rf,param_grid=params_rf,cv=5)

#parameters for AdaBoost
params_ada={'n_estimators':[50,100,250,400,500],
            'learning_rate':[0.1,0.001,0.2,0.5,0.8,1]}
grid_ada=GridSearchCV(ada,param_grid=params_ada,cv=5)

# paraameter for XGBoost
params_xgb={'n_estimators':[50,100,250,600,800,1000],
           'learning_rate':[0.1,0.001,0.2,0.5,0.8,1]}
rs_xgb=RandomizedSearchCV(xgb,param_distributions=params_xgb,cv=5)
# Out:
# /opt/homebrew/lib/python3.10/site-packages/xgboost/sklearn.py:1421: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")

# %%
grid_knn.fit(x_train,y_train)
grid_dt.fit(x_train,y_train)
grid_rf.fit(x_train,y_train)
grid_ada.fit(x_train,y_train)
rs_xgb.fit(x_train,y_train)

print("Best parameters for KNN:", grid_knn.best_params_)
print("Best parameters for Decision Tree:", grid_dt.best_params_)
print("Best parameters for Random Forest:", grid_rf.best_params_)
print("Best parameters for AdaBoost:", grid_ada.best_params_)
print("Best parameters for XGBoost:", rs_xgb.best_params_)
# Out:
# /opt/homebrew/lib/python3.10/site-packages/xgboost/sklearn.py:1421: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/homebrew/lib/python3.10/site-packages/xgboost/sklearn.py:1421: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/homebrew/lib/python3.10/site-packages/xgboost/sklearn.py:1421: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/homebrew/lib/python3.10/site-packages/xgboost/sklearn.py:1421: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# /opt/homebrew/lib/python3.10/site-packages/xgboost/sklearn.py:1421: UserWarning: `use_label_encoder` is deprecated in 1.7.0.
#   warnings.warn("`use_label_encoder` is deprecated in 1.7.0.")
# ...

# %% [markdown]
# ### Applying bagging and boosting

# %%
lr=LogisticRegression(random_state=42)
dt=DecisionTreeClassifier(criterion='entropy',max_depth=8,min_samples_leaf=5,random_state=42)
knn=KNeighborsClassifier(n_neighbors=44)
rf=RandomForestClassifier(n_estimators=500,min_samples_leaf=2,random_state=42)
ada=AdaBoostClassifier(n_estimators=50,learning_rate=0.2)
xgb=XGBClassifier(n_estimators=1000,learning_rate=0.001)

## Apply bagging and boosting
bagging=BaggingClassifier(DecisionTreeClassifier(criterion='entropy',
                                                max_depth=46,min_samples_leaf=2,
                                                 random_state=42),n_estimators=100,random_state=42)
bagging.fit(x_train,y_train)
# Out:
# BaggingClassifier(base_estimator=DecisionTreeClassifier(criterion='entropy',
#                                                         max_depth=46,
#                                                         min_samples_leaf=2,
#                                                         random_state=42),
#                   n_estimators=100, random_state=42)

# %%
classifiers = [('Logistic Regression', lr), ('K Nearest Neighbours', knn),
               ('Decision Tree', dt), ('Random Forest', rf), ('AdaBoost', ada),
              ('Bagging Classifier', bagging), ('XGBoost', xgb)]

# %%
from sklearn.metrics import accuracy_score
for classifier_name , classifier in classifiers:
    #Fit classifier to training set
    classifier.fit(x_train,y_train)
    
    #predict y_pred
    y_pred=classifier.predict(x_test)
    accuracy=accuracy_score(y_test,y_pred)
    
    #Evaluation the test set
    print('{:s} : {:.2f}'.format(classifier_name, accuracy))
# Out:
# Logistic Regression : 0.61
# K Nearest Neighbours : 0.62
# Decision Tree : 0.59
# Random Forest : 0.66
# AdaBoost : 0.61
# Bagging Classifier : 0.66
# XGBoost : 0.65

# %%
# View the classification report for test data and predictions
from sklearn.metrics import classification_report

y_pred_rf= rf.predict(x_test)
print(classification_report(y_test, y_pred_rf))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.88      0.76       399
#            1       0.62      0.31      0.42       254
#
#     accuracy                           0.66       653
#    macro avg       0.65      0.60      0.59       653
# weighted avg       0.65      0.66      0.63       653

# %% [markdown]
# #### The precision of class 0 is 71% and that of class 1 is 62% It means the model predicts 71% of class 0 and 62% of class 1 correctly
